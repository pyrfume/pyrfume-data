# %%
import pandas as pd

# %% [markdown]
# # Dataset for human olfaction

# %% [markdown]
# ## Dravnieks [c]

# %%
task_file = './fig1/c_Dravnieks/data.csv'
df = pd.read_csv(task_file)
df.head()
# Out:
#                smiles  regression_citrus  regression_lemon  \
# 0         O=Cc1ccccc1             0.0504            0.0360
# 1           CCCC(=O)O             0.0000            0.0071
# 2    O=c1ccc2ccccc2o1             0.0286            0.0357
# 3  CC(C)c1ccc(C=O)cc1             0.1071            0.1643
# 4        Cc1cccc(O)c1             0.0000            0.0000
#
#    regression_grapefruit  regression_orange  regression_fruity  \
# 0                 0.0072             0.0144             0.2230
# 1                 0.0000             0.0000             0.0071
# 2                 0.0000             0.0000             0.1429
# 3                 0.0214             0.0500             0.0714
# 4                 0.0000             0.0000             0.0216
#
#    regression_pineapple  regression_grape  regression_strawberry  \
# 0                0.0216            0.0072                 0.0576
# 1                0.0000            0.0000                 0.0000
# ...

# %% [markdown]
# ## DREAM Olfaction Prediction Challenge (Keller et al.) [h]

# %%
task_file = './fig1/h_Keller_et_al/data.csv'
df = pd.read_csv(task_file)
df.head()
# Out:
#              smiles  regression_Intensity  regression_Pleasantness  \
# 0    O=Cc1ccc(O)cc1             24.653061                48.956522
# 1              CC=O             33.265306                45.315789
# 2           CC(C)=O             16.714286                55.437500
# 3  O=C(O)CCCCC(=O)O              6.877551                53.218750
# 4         NCCC(=O)O             21.163265                51.351351
#
#    regression_Bakery  regression_Sweet  regression_Fruit  regression_Fish  \
# 0           0.630435         24.347826          6.239130         0.282609
# 1           8.421053         20.078947          1.763158         0.000000
# 2           3.375000         15.531250          6.468750         2.281250
# 3           1.750000         18.312500          1.312500         0.000000
# 4           0.675676          8.567568          2.351351         1.000000
#
#    regression_Garlic  regression_Spices  regression_Cold  ...  \
# ...

# %% [markdown]
# ## Human olfactory receptors (Gupta et al.) [j]

# %%
receptor_files = [
    './fig1/j_Gupta_et_al/OR1A1.csv',
    './fig1/j_Gupta_et_al/OR1A2.csv',
    './fig1/j_Gupta_et_al/OR1G1.csv',
    './fig1/j_Gupta_et_al/OR2J2.csv',
    './fig1/j_Gupta_et_al/OR2W1.csv',
    './fig1/j_Gupta_et_al/OR51E1.csv',
    './fig1/j_Gupta_et_al/OR51E2.csv', 
    './fig1/j_Gupta_et_al/OR52D1.csv',
]
receptor_idx = 0
df = pd.read_csv(receptor_files[receptor_idx])
df.head()
# Out:
#                           smiles  binary_classification_response
# 0       CC[C@@H](C(=O)O)c1ccccc1                               0
# 1     C=C1CC[C@H]2C[C@@H]1C2(C)C                               0
# 2  CC1(C)[C@H]2CC[C@]1(C)C(=O)C2                               0
# 3          C=C(C)C1CC=C(C)C(O)C1                               1
# 4  CC1(C)C(=O)[C@]2(C)CC[C@H]1C2                               0

# %% [markdown]
# # Dataset for mouse piriform cortex activity [f]

# %%
dataset_files = [
    './fig1/f_Pashkovski_et_al/clustered_pcx_l2.csv',
    './fig1/f_Pashkovski_et_al/clustered_pcx_l3.csv', 
    './fig1/f_Pashkovski_et_al/local_boutons.csv',
    './fig1/f_Pashkovski_et_al/local_pcx_l2.csv',
    './fig1/f_Pashkovski_et_al/local_pcx_l3.csv',
]
dataset_idx = 1
df = pd.read_csv(dataset_files[dataset_idx])
df.head() # neuron recoridng values for each dataset
# Out:
#                       smiles  neuron_0  neuron_1  neuron_2  neuron_3  \
# 0   C[C@H](CCC=C(C)C)CC(=O)O       0.3       0.6       0.7       0.4
# 1            CCCCC(CC)C(=O)O       0.4       0.2       0.1       0.4
# 2           CCCCC(C)CCC(=O)O       0.4       0.4       0.7       0.6
# 3            CCCCCC(C)C(=O)O       0.7       0.5       0.5       0.3
# 4  CC(C)C(=O)OCCCC1=CC=CC=C1       0.4       0.2       0.2       0.8
#
#    neuron_4  neuron_5  neuron_6  neuron_7  neuron_8  ...  neuron_478  \
# 0       0.4       0.7       0.2       0.8       0.4  ...         0.0
# 1       0.8       0.4       0.4       0.7       0.4  ...         0.0
# 2       0.7       0.3       0.7       0.9       0.3  ...         0.2
# 3       0.6       0.9       0.1       1.0       0.4  ...         0.1
# 4       0.3       0.5       0.4       0.6       0.6  ...         0.4
#
#    neuron_479  neuron_480  neuron_481  neuron_482  neuron_483  neuron_484  \
# ...

# %% [markdown]
# # Dataset for insect olfaction

# %% [markdown]
# ## MacWilliam et al. [a]

# %%
task_file = './fig1/a_MacWilliam_et_al/data.csv'
df = pd.read_csv(task_file)
df.head()
# Out:
#            smiles  binary_classification_preference_idx
# 0          CN(C)C                                     1
# 1  CCOC(=O)C(C)=O                                     0
# 2      CCC/C=C\CO                                     0
# 3         NCCCCCN                                     1
# 4      CC/C=C\CCO                                     0

# %% [markdown]
# ## Xu et al. [b]

# %%
task_file = './fig1/b_Xu_et_al/data.csv'
df = pd.read_csv(task_file)
df.head()
# Out:
#                smiles  binary_classification_current_label
# 0  C=CC(CCCCC)OC(C)=O                                    1
# 1        C/C=C(\C)C=O                                    0
# 2               CCCCO                                    0
# 3              CCCCCO                                    0
# 4             CCCCCCO                                    1

# %% [markdown]
# ## Wei et al. [d]

# %%
task_file = './fig1/d_Wei_et_al/data.csv'
df = pd.read_csv(task_file)
df.head()
# Out:
#                        smiles  binary_classification_above90@0.01
# 0    CCOC(=O)C1OC1(C)c1ccccc1                                   1
# 1           CCOc1cc(C=O)ccc1O                                   1
# 2           CCCCCCC1CCC(=O)O1                                   1
# 3   CC(=O)C=CC1=C(C)CCCC1(C)C                                   0
# 4  CC(C=O)Cc1ccc(C(C)(C)C)cc1                                   1

# %% [markdown]
# ## Missbach et al. [e]

# %%
species_files = ['./fig1/e_Missbach_et_al/drosophila_melanogaster.csv',
                 './fig1/e_Missbach_et_al/lepismachilis_y-signata.csv',
                 './fig1/e_Missbach_et_al/phyllium_siccifolium.csv',
                 './fig1/e_Missbach_et_al/thermobia_domestica.csv',
                ]
species_idx = 0
df = pd.read_csv(species_files[species_idx])
df.head() # different tasks/neuron for each the first specie
# Out:
# 879

# %% [markdown]
# ## del Mármol et al. [g]

# %%
task_file = './fig1/g_del_Mármol_et_al/data.csv'
df = pd.read_csv(task_file)
df.head()
# Out:
#           smiles  regression_OR1  regression_OR5
# 0        CCCCCCO           1.262           4.202
# 1      CCCCCCCCO           8.261           4.661
# 2   C=CC(O)CCCCC           0.500           4.692
# 3         CCCCCO           0.366           1.434
# 4  CC(=O)c1cccs1           5.139           4.545

# %% [markdown]
# ## Carey et al. [i]

# %%
task_file = './fig1/i_Carey_et_al/data.csv'
df = pd.read_csv(task_file)
df.head()
# Out:
#                             smiles  regression_AgOr1  regression_AgOr2  \
# 0      CC(=C)[C@@H]1CC=C(C)C(=O)C1         -5.000000         -2.400000
# 1    CC1(C)[C@H]2CC[C@](C)(C2)C1=O        -12.333333         12.333333
# 2       CC(=C)[C@H]1CC=C(C)C(=O)C1         -2.000000         -0.666667
# 3  CC1(C)[C@@H]2CC[C@@](C)(C2)C1=O         -5.666667          1.000000
# 4                            CCCCO        130.333333          4.666667
#
#    regression_AgOr3  regression_AgOr4  regression_AgOr5  regression_AgOr6  \
# 0         -2.000000         11.200000          2.333333         -3.000000
# 1         -3.200000         14.400000         -6.333333          1.000000
# 2          6.333333         -0.333333          2.333333          3.200000
# 3         -1.666667         18.666667         -6.333333         -0.333333
# 4          1.666667         55.000000         76.000000          9.333333
#
#    regression_AgOr8  regression_AgOr9  regression_AgOr10  ...  \
# ...

# %% [markdown]
# ## Hallem and Carlson [k]

# %%
task_file = './fig1/k_Hallem_and_Carlson/data.csv'
df = pd.read_csv(task_file)
df.head()
# Out:
#             smiles  regression_Or2a  regression_Or7a  regression_Or9a  \
# 0           NCCCCN               -2              -53               23
# 1          NCCCCCN               -7              -58               18
# 2        O=C1CCCO1                1               17               50
# 3    CCC1CCC(=O)O1                7              -56              115
# 4  CCCCC1CCC(=O)O1               -1              -39               23
#
#    regression_Or10a  regression_Or19a  regression_Or22a  regression_Or23a  \
# 0               -40               -38                 8               -11
# 1               -31               -34                 9               -16
# 2               -20               -36                39                -5
# 3                 4               -31               136                 3
# 4                 4               -27                37                -6
#
#    regression_Or33b  regression_Or35a  ...  regression_Or59b  \
# ...

# %% [markdown]
# ## Oliferenko et al. [n]

# %%
task_file = './fig1/n_Oliferenko_et_al/data.csv'
df = pd.read_csv(task_file)
df.head()
# Out:
#                         smiles  binary_classification_exp_med
# 0           CCCCCC(=O)N(C)CCCC                              1
# 1        CC(C)=CC(=O)N1CCCCCC1                              1
# 2          CCCCCC(=O)N(CC)CCCC                              0
# 3  CCCCN(CC)C(=O)/C=C/c1ccccc1                              0
# 4        C=CCN(CC=C)C(=O)CCCCC                              0

# %% [markdown]
# # Datasets for non olfaction related tasks

# %% [markdown]
# ## Enteric GPCR binding (Kooistra_et_al) [p]

# %%
task_files = ['./fig1/p_Kooistra_et_al/5ht1a.csv',
              './fig1/p_Kooistra_et_al/cnr2.csv',
              './fig1/p_Kooistra_et_al/drd2.csv',
              './fig1/p_Kooistra_et_al/ghsr.csv',
              './fig1/p_Kooistra_et_al/oprk.csv',
             ]
receptor_idx = 0
df = pd.read_csv(task_files[receptor_idx])
df.head() # label for a particular GPCR
# Out:
#                                               smiles  regression_binding_score
# 0               C#CCOc1cccc2c1-c1cccc3c1C(C2)N(C)CC3                      7.30
# 1             C#CCOc1cccc2c1-c1cccc3c1C(C2)N(CCC)CC3                      7.26
# 2                 C#Cc1c[nH]c(CN2CCN(c3ccccc3)CC2)c1                      6.57
# 3         C(=Cc1ccccc1)CN1CCN(c2nc3ccsc3n3cccc23)CC1                      7.08
# 4  C1=C(c2c[nH]c3ccccc23)CC2CCC1N2CCOc1cccc2[nH]c...                      6.95

# %% [markdown]
# ## Other molecular properties [l, m, o, q, r]

# %%
moleculenet_files = ['./fig1/lmoqr_other_molcule_properties/l_sider.csv', 
                     './fig1/lmoqr_other_molcule_properties/m_freesolv.csv',
                     './fig1/lmoqr_other_molcule_properties/o_esol.csv',
                     './fig1/lmoqr_other_molcule_properties/q_bace-1.csv', 
                     './fig1/lmoqr_other_molcule_properties/r_qm7.csv',]
task_idx = 0
df = pd.read_csv(moleculenet_files[task_idx])
df.head() # label(s) for a task
# Out:
#                                               smiles  \
# 0                      C1C2CNCC1C3=CC4=NC=CN=C4C=C23
# 1                     CC(C)NCC(COC1=CC=C(C=C1)CCOC)O
# 2                                          C(=N)(N)N
# 3  CCOC1=NC2=CC=CC(=C2N1CC3=CC=C(C=C3)C4=CC=CC=C4...
# 4                       C(C(=O)O)C(CC(=O)O)(C(=O)O)O
#
#    binary_classification_Hepatobiliary disorders  \
# 0                                              1
# 1                                              1
# 2                                              0
# 3                                              0
# 4                                              1
#
#    binary_classification_Metabolism and nutrition disorders  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  0
# 4                                                  1
#
# ...

# %% [markdown]
# # Simulated dataset for extended data figure 3

# %% [markdown]
# ## Wildman-Cripper LogP

# %%
task_file = './sfig3/logp/data.csv'
df = pd.read_csv(task_file)
df.head(5)
# Out:
#                                            smiles  regression_logP
# 0                             COC(OC)C(C)c1ccccc1           2.4090
# 1  CC(C)=CCCC(C)=CCOC(Cc1ccccc1)OCC=C(C)CCC=C(C)C           7.9738
# 2                         CCCCCCCCCCCCOS(=O)(=O)O           3.7267
# 3                              COc1ccc(C(C)=O)cc1           1.8978
# 4                                  CC(=O)c1ccccc1           1.8892

# %% [markdown]
# ## ESOL

# %%
task_file = './sfig3/esol/data.csv'
df = pd.read_csv(task_file)
df.head(5)
# Out:
#                                            smiles  regression_ESOL
# 0                             COC(OC)C(C)c1ccccc1        -2.781643
# 1  CC(C)=CCCC(C)=CCOC(Cc1ccccc1)OCC=C(C)CCC=C(C)C        -8.335178
# 2                         CCCCCCCCCCCCOS(=O)(=O)O        -4.216423
# 3                              COc1ccc(C(C)=O)cc1        -2.247571
# 4                                  CC(=O)c1ccccc1        -2.078162

# %% [markdown]
# ## QED

# %%
task_file = './sfig3/qed/data.csv'
df = pd.read_csv(task_file)
df.head(5)
# Out:
#                                            smiles  regression_QED
# 0                             COC(OC)C(C)c1ccccc1        0.662338
# 1  CC(C)=CCCC(C)=CCOC(Cc1ccccc1)OCC=C(C)CCC=C(C)C        0.228554
# 2                         CCCCCCCCCCCCOS(=O)(=O)O        0.431651
# 3                              COc1ccc(C(C)=O)cc1        0.601659
# 4                                  CC(=O)c1ccccc1        0.517047

# %% [markdown]
# ## GPCR Binding (model-estimated)

# %%
task_files = ['./sfig3/gpcr_binding_model_estimated/5ht1a.csv',
              './sfig3/gpcr_binding_model_estimated/cnr2.csv',
              './sfig3/gpcr_binding_model_estimated/drd2.csv',
              './sfig3/gpcr_binding_model_estimated/ghsr.csv',
              './sfig3/gpcr_binding_model_estimated/oprk.csv',
             ]
receptor_idx = 0
df = pd.read_csv(task_files[receptor_idx])
df.head() # model estaimted label for a particular GPCR
# Out:
#                   smiles  regression_pred_pKd
# 0             CCOC(C)OCC             3.167474
# 1     CCCCCOC(C)OCCC(C)C             3.310190
# 2  COC(C)OC(C)OCc1ccccc1             5.185222
# 3           CCCCOC(C)OCC             3.423579
# 4      CCCCOC(C)OCCC(C)C             3.504179

# %% [markdown]
# # Metabolic Networks

# %%
task_file = './fig23_metabolic_network/data.csv'
df = pd.read_csv(task_file)
df.head(15) # csv contains the SMILES for different essential oil
# Out:
#    network_for_specie from_compound_metacyc_id  \
# 0            ORG-5993                  CPD-706
# 1            ORG-5993                 CPD-8134
# 2            ORG-5993                 CPD-4101
# 3            ORG-5993            EPOXYSQUALENE
# 4            ORG-5993            EPOXYSQUALENE
# 5            ORG-5993            EPOXYSQUALENE
# 6            ORG-5993                 CPD-7078
# 7            ORG-5993                 CPD-7078
# 8            ORG-5993          GDP-L-GALACTOSE
# 9            ORG-5993          GDP-L-GALACTOSE
# 10           ORG-5993          GDP-L-GALACTOSE
# 11           ORG-5993              GDP-MANNOSE
# 12           ORG-5993               MANNOSE-1P
# 13           ORG-5993               MANNOSE-1P
# 14           ORG-5993            GDP-D-GLUCOSE
#
#              to_compound_metacyc_id  \
# 0                          CPD-8134
# 1                          CPD-4161
# 2                          CPD-4124
# 3                         CPD-13048
# ...

# %% [markdown]
# # Essential Oils

# %%
task_file = './fig4_essential_oil/data.csv'
df = pd.read_csv(task_file)
df.head(15) # csv contains the SMILES for different essential oil
# Out:
#             essential_oil                                  smiles
# 0     Abies alba cone oil                  CC(=C)[C@H]1CCC(=CC1)C
# 1     Abies alba cone oil                       CC1=CCC2CC1C2(C)C
# 2     Abies alba cone oil                     CC1(C)C2CCC(C2)C1=C
# 3     Abies alba cone oil                     CC1(C)C2CCC(=C)C1C2
# 4     Abies alba cone oil               CC(=O)OC1CC2CCC1(C)C2(C)C
# 5     Abies alba cone oil               CC1=CC[C@@H](CC1)C(C)(C)O
# 6     Abies alba cone oil  C\C1=C/CCC(=C)[C@H]2CC(C)(C)[C@@H]2CC1
# 7     Abies alba cone oil                   CC1(C)C2CCC1(C)C(O)C2
# 8     Abies alba cone oil                       CC(C)=CCCC(=C)C=C
# 9     Abies alba cone oil            CC1(C)CCCC2(C)C3CCC(C13)C2=C
# 10    Abies alba cone oil                      CC(C)=C1CCC(=CC1)C
# 11    Abies alba cone oil                     CC(C)=CCCC(C)(O)C=C
# 12    Abies alba cone oil                     CC1=CCC2C(C1)C2(C)C
# ...

# %% [markdown]
# # Embeddings

# %%
all_emb_file = './embeddings/data.csv'
all_emb_df = pd.read_csv(all_emb_file)
all_emb_df.head()
# Out:
#                                               smiles  POM_dim0  POM_dim1  \
# 0                      CC/C=C\CC1C(=O)CCC1CC(=O)[O-]  0.000000  1.288520
# 1  C=C[C@]1(C)CC[C@@H]2C(=CC[C@H]3[C@@](C)(C=O)CC...  3.044895  0.000000
# 2                                     CCCCCC/C=C/C=O  0.000000  0.000000
# 3                                     CC1CCC(=O)C1=O  0.000000  0.000000
# 4                       CCCC(=O)OC1C=CC2C3CCC(C3)C12  1.491022  1.703882
#
#    POM_dim2  POM_dim3  POM_dim4  POM_dim5  POM_dim6  POM_dim7  POM_dim8  ...  \
# 0  0.000000  0.000000  0.000000  3.270320  1.714564  0.530266  0.295287  ...
# 1  3.390288  6.324815  0.000000  2.213868  0.000000  0.000000  0.000000  ...
# 2  3.067747  0.000000  0.000000  2.591244  2.268885  0.221056  1.106228  ...
# 3  0.000000  0.000000  0.000000  0.000000  0.000000  2.686685  2.118346  ...
# 4  0.000000  0.000000  0.521094  1.581025  0.735047  0.498118  0.000000  ...
#
# ...

# %% [markdown]
# # HParam and model perforamnces

# %%
hparam_perf_file = './fig1/best_hparam_and_performance.csv'
hparam_perf_df = pd.read_csv(hparam_perf_file)
hparam_perf_df
# Out:
# /Library/Python/3.8/site-packages/IPython/core/interactiveshell.py:3169: DtypeWarning: Columns (22,27,33,36,37,42,43,44,55) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#           label  seed        r2      rmse           dataset   task_type  \
# 0       overall     0  0.758275  0.059534               QED  REGRESSION
# 1       overall     1  0.753172  0.059311               QED  REGRESSION
# 2       overall     2  0.750360  0.059305               QED  REGRESSION
# 3       overall     3  0.748112  0.060376               QED  REGRESSION
# 4       overall     4  0.722332  0.062615               QED  REGRESSION
# ...         ...   ...       ...       ...               ...         ...
# 490223  target0    33       NaN       NaN  TROPIQ_FRAGRANCE      BINARY
# 490224  target0    34       NaN       NaN  TROPIQ_FRAGRANCE      BINARY
# ...
