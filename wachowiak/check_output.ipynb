# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# open behavior.csv to make sure Response Maps can be reconstructed
df = pd.read_csv('behavior.csv', index_col=0).astype('object')     
df.head()
# Out:
#                                            Response Map
# CID
# -1    [0.         0.         0.4000001  ... 0.      ...
#  240  [0.27999997 0.         0.         ... 0.4     ...
#  261  [0.12       0.20000005 0.         ... 0.      ...
#  264  [0.48000002 0.19999993 0.         ... 0.200000...
#  273  [0.4799999  0.59999996 0.         ... 0.32    ...

# %%
# open csv images

im = np.loadtxt('images//C7_propionic_acid.csv', delimiter=',')

plt.imshow(im)
