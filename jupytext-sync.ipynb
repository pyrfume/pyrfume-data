# %%
from pathlib import Path
import subprocess
from tqdm.auto import tqdm

home = Path('.')
for archive in tqdm(pyrfume.list_archives()):
    path = pyrfume.get_data_path() / archive
    for notebook in path.glob('*.ipynb'):
        subprocess.run(['jupytext',
                        '--set-formats=ipynb,py',
                        str(notebook)])
        x = subprocess.run(['git',
                            'rm',
                            '--cached',
                            '%s/main.ipynb' % str(archive)],
                            capture_output=True,
                            shell=True)
        print(x.stdout.decode('utf8').split('\n'))
        subprocess.run(['git',
                        'add',
                        '%s/main.py' % archive])
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# ...

# %%
['git',
                            'rm',
                            '--cached',
                            '%s/main.ipynb' % str(archive)]
# Out:
# ['git', 'rm', '--cached', 'wakayama_2019/main.ipynb']
